# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("iris.csv")
df=df.drop(df.columns[-1],axis=1)
train_df=StandardScaler().fit_transform(df.values)
pd.DataFrame(train_df).head()
# Out:
#           0         1         2         3
# 0 -0.900681  1.019004 -1.340227 -1.315444
# 1 -1.143017 -0.131979 -1.340227 -1.315444
# 2 -1.385353  0.328414 -1.397064 -1.315444
# 3 -1.506521  0.098217 -1.283389 -1.315444
# 4 -1.021849  1.249201 -1.340227 -1.315444

# %%
import simpsom as sp

net=sp.SOMNet(20,20,train_df)
net.train(start_learning_rate=0.01,epochs=10000)

net.save('filename_weights')

net.nodes_graph(colnum=0)
net.diff_graph()
# Out:
# Periodic Boundary Conditions inactive.
# The weights will be initialized with PCA.
# The map will be trained with the batch algorithm.
# Training SOM... done!
